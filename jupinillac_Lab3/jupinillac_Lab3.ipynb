# %% [markdown]
# <a href="https://colab.research.google.com/github/jupinillac/MetNumUN2023I/blob/main/jupinillac_Lab3/jupinillac_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Python 101.png](data:image/png;base64,...)

# %% [markdown]
# ![Data analysis.png](data:image/png;base64,...)

# %% [markdown]
# ![Data visualization.png](data:image/png;base64,...)
